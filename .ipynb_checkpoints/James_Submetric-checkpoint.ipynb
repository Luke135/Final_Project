# %%
# Import pandas and numpy, just in case
import pandas as pd
import numpy as np

# load fire incident data
firedata = pd.read_csv("firedata.csv") 
firedata.groupby("neighborhood").count()
# Out:
#                      call_no  incident_type  type_description  address  \
# neighborhood
# Allegheny Center          56             55                56       56
# Allegheny West            39             39                39       39
# Allentown                115            115               115      115
# Arlington                 45             45                45       45
# Arlington Heights         13             13                13       13
# ...                      ...            ...               ...      ...
# Upper Lawrenceville       44             44                44       44
# West End                  19             19                19       19
# West Oakland              57             57                57       57
# Westwood                  23             23                23       23
# Windgap                   18             18                18       18
#
#                      alarm_time  alarms  primary_unit  census_tract  \
# neighborhood
# Allegheny Center             55      56            56            55
# Allegheny West               39      39            39            39
# Allentown                   115     115           115           115
# Arlington                    45      45            45            45
# Arlington Heights            13      13            13            13
# ...                         ...     ...           ...           ...
# Upper Lawrenceville          44      44            44            44
# West End                     19      19            19            19
# West Oakland                 57      57            57            57
# Westwood                     23      23            23            23
# Windgap                      18      18            18            18
#
#                      council_district  ward  tract  public_works_division  \
# neighborhood
# Allegheny Center                   56    56     56                     56
# Allegheny West                     39    39     39                     39
# Allentown                         115   115    115                    115
# Arlington                          45    45     45                     45
# Arlington Heights                  13    13     13                     13
# ...                               ...   ...    ...                    ...
# Upper Lawrenceville                44    44     44                     44
# West End                           19    19     19                     19
# West Oakland                       57    57     57                     57
# Westwood                           23    23     23                     23
# Windgap                            18    18     18                     18
#
#                      pli_division  police_zone  fire_zone  latitude  longitude
# neighborhood
# Allegheny Center               56           56         56        53         53
# Allegheny West                 39           39         39        38         38
# Allentown                     115          115        115       112        112
# Arlington                      45           45         45        45         45
# Arlington Heights              13           13         13        13         13
# ...                           ...          ...        ...       ...        ...
# Upper Lawrenceville            44           44         44        44         44
# West End                       19           19         19        19         19
# West Oakland                   57           57         57        57         57
# Westwood                       23           23         23        23         23
# Windgap                        18           18         18        18         18
#
# [91 rows x 17 columns]

# %%
# Get the value counts (number of entries) per each neighborhood. From here we can see that there are 
# 91 neighborhoods considered by the dataset.

fire_series = firedata["neighborhood"].value_counts()

fire_series
# Out:
# Carrick                      262
# Squirrel Hill South          233
# Central Business District    232
# South Side Flats             225
# Hazelwood                    217
#                             ...
# Mt. Oliver                    11
# East Carnegie                 11
# St. Clair                     11
# Regent Square                  7
# Mount Oliver Borough           6
# Name: neighborhood, Length: 91, dtype: int64

# %%
# That's a lot of neighborhoods to contend with. Maybe we just want to see where the highest 
# number of fire incidents are. Create a new series that ends at the median neighborhood for this
# dataset.

fire_series_filtered = fire_series.iloc[:int(fire_series.size / 2)]
fire_series_filtered
# Out:
# Carrick                      262
# Squirrel Hill South          233
# Central Business District    232
# South Side Flats             225
# Hazelwood                    217
# East Liberty                 188
# Mount Washington             183
# Lincoln-Lemington-Belmar     177
# Homewood South               174
# Homewood North               171
# Brookline                    163
# Shadyside                    157
# Sheraden                     156
# Knoxville                    156
# Perry South                  151
# Bloomfield                   151
# East Hills                   147
# Brighton Heights             135
# Beechview                    129
# Bluff                        122
# Marshall-Shadeland           121
# Larimer                      118
# Beltzhoover                  117
# Allentown                    115
# Squirrel Hill North          115
# North Oakland                114
# East Allegheny               113
# Central Northside            112
# Perry North                  102
# Greenfield                   100
# Garfield                      98
# Spring Hill-City View         96
# Middle Hill                   95
# Crawford-Roberts              92
# South Side Slopes             85
# Central Oakland               85
# Terrace Village               82
# South Oakland                 77
# Crafton Heights               76
# Highland Park                 73
# Central Lawrenceville         69
# Manchester                    67
# Troy Hill                     67
# Point Breeze                  66
# Elliott                       62
# Name: neighborhood, dtype: int64

# %%
# Plot the data and change the size to make it legible. Boom! Don't move to Carrick if you're flammable. 
fire_series_filtered.plot(kind="barh",figsize=(10,10))
