# %% [markdown]
# # Final Project!!

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import geopandas

# %% [markdown]
# This is the beginning of my part of the final project. My sub-metric will be overdose and drug use in Allegheny County.

# %%
data = pd.read_csv('Firearms.csv',index_col = 'address',parse_dates = True)
data.head(5)
# Out:
#                                                 total_count  other_count  \
# address
# 1700 BLOCK ARLINGTON AVE PITTSBURGH, PA 15210             2            0
# BREVET WAY & MINTON ST PITTSBURGH, PA 15204               1            0
# TERRACE ST & WHITRIDGE ST PITTSBURGH, PA 15213            1            0
# 3500 BLOCK GERBER AVE PITTSBURGH, PA 15212                1            0
# 7500 BLOCK KELLY ST PITTSBURGH, PA 15208                  1            0
#
#                                                 pistol_count  revolver_count  \
# address
# 1700 BLOCK ARLINGTON AVE PITTSBURGH, PA 15210              1               1
# BREVET WAY & MINTON ST PITTSBURGH, PA 15204                1               0
# TERRACE ST & WHITRIDGE ST PITTSBURGH, PA 15213             1               0
# 3500 BLOCK GERBER AVE PITTSBURGH, PA 15212                 1               0
# 7500 BLOCK KELLY ST PITTSBURGH, PA 15208                   1               0
#
#                                                 rifle_count  shotgun_count  \
# address
# 1700 BLOCK ARLINGTON AVE PITTSBURGH, PA 15210             0              0
# BREVET WAY & MINTON ST PITTSBURGH, PA 15204               0              0
# TERRACE ST & WHITRIDGE ST PITTSBURGH, PA 15213            0              0
# 3500 BLOCK GERBER AVE PITTSBURGH, PA 15212                0              0
# 7500 BLOCK KELLY ST PITTSBURGH, PA 15208                  0              0
#
#                                                 year  month  dow  \
# address
# 1700 BLOCK ARLINGTON AVE PITTSBURGH, PA 15210   2015      1    0
# BREVET WAY & MINTON ST PITTSBURGH, PA 15204     2015      1    0
# TERRACE ST & WHITRIDGE ST PITTSBURGH, PA 15213  2015      1    0
# 3500 BLOCK GERBER AVE PITTSBURGH, PA 15212      2015      1    0
# 7500 BLOCK KELLY ST PITTSBURGH, PA 15208        2015      1    0
#
#                                                         neighborhood  \
# address
# 1700 BLOCK ARLINGTON AVE PITTSBURGH, PA 15210   Mount Oliver Borough
# BREVET WAY & MINTON ST PITTSBURGH, PA 15204                 Sheraden
# TERRACE ST & WHITRIDGE ST PITTSBURGH, PA 15213       Terrace Village
# 3500 BLOCK GERBER AVE PITTSBURGH, PA 15212          Brighton Heights
# 7500 BLOCK KELLY ST PITTSBURGH, PA 15208                         NaN
#
#                                                 council_district  ward  \
# address
# 1700 BLOCK ARLINGTON AVE PITTSBURGH, PA 15210                3.0   0.0
# BREVET WAY & MINTON ST PITTSBURGH, PA 15204                  2.0  20.0
# TERRACE ST & WHITRIDGE ST PITTSBURGH, PA 15213               6.0   4.0
# 3500 BLOCK GERBER AVE PITTSBURGH, PA 15212                   1.0  27.0
# 7500 BLOCK KELLY ST PITTSBURGH, PA 15208                     NaN   NaN
#
#                                                        tract  \
# address
# 1700 BLOCK ARLINGTON AVE PITTSBURGH, PA 15210   4.200317e+10
# BREVET WAY & MINTON ST PITTSBURGH, PA 15204     4.200356e+10
# TERRACE ST & WHITRIDGE ST PITTSBURGH, PA 15213  4.200305e+10
# 3500 BLOCK GERBER AVE PITTSBURGH, PA 15212      4.200327e+10
# 7500 BLOCK KELLY ST PITTSBURGH, PA 15208                 NaN
#
#                                                 public_works_division  \
# address
# 1700 BLOCK ARLINGTON AVE PITTSBURGH, PA 15210                     0.0
# BREVET WAY & MINTON ST PITTSBURGH, PA 15204                       5.0
# TERRACE ST & WHITRIDGE ST PITTSBURGH, PA 15213                    3.0
# 3500 BLOCK GERBER AVE PITTSBURGH, PA 15212                        1.0
# 7500 BLOCK KELLY ST PITTSBURGH, PA 15208                          NaN
#
#                                                police_zone fire_zone  \
# address
# 1700 BLOCK ARLINGTON AVE PITTSBURGH, PA 15210            3       4-6
# BREVET WAY & MINTON ST PITTSBURGH, PA 15204              6      1-16
# TERRACE ST & WHITRIDGE ST PITTSBURGH, PA 15213           2      2-10
# 3500 BLOCK GERBER AVE PITTSBURGH, PA 15212               1      1-14
# 7500 BLOCK KELLY ST PITTSBURGH, PA 15208                 5       NaN
#
#                                                  latitude  longitude
# address
# 1700 BLOCK ARLINGTON AVE PITTSBURGH, PA 15210   40.417619 -79.986436
# BREVET WAY & MINTON ST PITTSBURGH, PA 15204     40.456904 -80.052328
# TERRACE ST & WHITRIDGE ST PITTSBURGH, PA 15213  40.441185 -79.968527
# 3500 BLOCK GERBER AVE PITTSBURGH, PA 15212      40.479530 -80.033477
# 7500 BLOCK KELLY ST PITTSBURGH, PA 15208              NaN        NaN

# %%
data['neighborhood'].value_counts().sort_values(ascending=False).head().plot(kind = 'pie')
plt.legend(bbox_to_anchor=(1,1))

# %%
data['total_count'].sort_values(ascending = False).head().plot(kind='pie')
plt.legend(bbox_to_anchor=(1,1))

# %%
data['pistol_count'].sort_values(ascending = False).head().plot(kind = 'pie')
plt.legend(bbox_to_anchor=(1,1))

# %%
data['rifle_count'].sort_values(ascending = False).head().plot(kind = 'pie')
plt.legend(bbox_to_anchor=(1,1))

# %%
print('Total amount of pistols reported:', data['pistol_count'].sum())
print('Total amount of rifles reported:', data['rifle_count'].sum())
# Out:
# Total amount of pistols reported: 3899
# Total amount of rifles reported: 384

# %%
print('Average amount of pistols reported per case:', data['pistol_count'].mean())
print('Average amount of rifles reported per case:', data['rifle_count'].mean())
# Out:
# Average amount of pistols reported per case: 0.9452121212121212
# Average amount of rifles reported per case: 0.09309090909090909

# %%
data['total_count'].sort_values(ascending = False).head(5)
# Out:
# address
# 300 BLOCK S NEGLEY AVE PITTSBURGH, PA 15206       55
# 1800 BLOCK FAIRLEE ST PITTSBURGH, PA 15212        44
# 1000 BLOCK SOUTH SIDE AVE PITTSBURGH, PA 15212    29
# 700 BLOCK N HOMEWOOD AVE PITTSBURGH, PA 15208     24
# 1600 BLOCK WORTHINGTON ST PITTSBURGH, PA 15206    19
# Name: total_count, dtype: int64

# %%
neighborhoods = geopandas.read_file("Neighborhoods/Neighborhoods_.shp")
neighborhoods.plot()

# %%
totals = data.groupby("neighborhood").sum()['total_count']
totals.sort_values(ascending=True).head()
# Out:
# neighborhood
# Mt. Oliver        3
# Regent Square     3
# Swisshelm Park    3
# Summer Hill       3
# Oakwood           4
# Name: total_count, dtype: int64

# %%
firearm_map = neighborhoods.merge(totals, how='left', left_on='hood', right_on='neighborhood')
firearm_map[['hood','total_count','geometry']].tail()
# Out:
#                     hood  total_count  \
# 85             Ridgemont          NaN
# 86              West End          5.0
# 87  California-Kirkbride         26.0
# 88            Glen Hazel         15.0
# 89           Perry North         41.0
#
#                                              geometry
# 85  POLYGON ((-80.03431 40.43366, -80.03424 40.433...
# 86  POLYGON ((-80.02869 40.44454, -80.02845 40.444...
# 87  POLYGON ((-80.02039 40.46285, -80.02022 40.462...
# 88  POLYGON ((-79.92030 40.41205, -79.92027 40.412...
# 89  POLYGON ((-80.01783 40.49736, -80.01787 40.497...

# %%
firearm_map.plot(column = 'total_count')

# %%
firearm_map.plot(column='total_count', # set the data to be used for coloring
               cmap='Blues',              # choose a color palette
               edgecolor="grey",        # outline the districts in white
               legend=True,              # show the legend
               legend_kwds={'label': "Firearms Seized"}, # label the legend
               figsize=(15, 10),         # set the size
               missing_kwds={"color": "lightgrey"} # set disctricts with no data to gray
               )

# %% [markdown]
# Mount Oliver is the safest neighborhood in terms of firearms!
